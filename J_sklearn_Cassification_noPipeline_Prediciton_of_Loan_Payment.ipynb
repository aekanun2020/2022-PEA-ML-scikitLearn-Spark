# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/2022-PEA-ML-scikitLearn-Spark/blob/main/J_sklearn_Cassification_noPipeline_Prediciton_of_Loan_Payment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Pandas options
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', None, 'display.max_columns', None)

# Plotting options
# %matplotlib inline
mpl.style.use('ggplot')
sns.set(style='whitegrid')

# %%
! wget https://storage.googleapis.com/2022oct23/LoanStats_web.csv
# Out:
# --2022-11-10 13:41:53--  https://storage.googleapis.com/2022oct23/LoanStats_web.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.23.128, 74.125.204.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.23.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1160243241 (1.1G) [text/csv]
# Saving to: ‘LoanStats_web.csv’
#
# LoanStats_web.csv   100%[===================>]   1.08G  19.2MB/s    in 59s
#
# 2022-11-10 13:42:54 (18.8 MB/s) - ‘LoanStats_web.csv’ saved [1160243241/1160243241]

# %% [markdown]
# # **2. Data Profiling and Cleansing**

# %%
loans = pd.read_csv('LoanStats_web.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,19,55,112,123,124,125,128,129,130,133,138,139,140) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
## นับจำนวน columns และจำนวน rows รวมถึง data type
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1432466 entries, 0 to 1432465
# Columns: 144 entries, id to settlement_term
# dtypes: float64(106), object(38)
# memory usage: 1.5+ GB

# %%
## preview ดูรายละเอียดข้อมูล จำนวน 5 rows

loans.sample(5).transpose()
# Out:
#                                                         1276283  \
# id                                                          NaN
# member_id                                                   NaN
# loan_amnt                                                6800.0
# funded_amnt                                              6800.0
# funded_amnt_inv                                          6800.0
# term                                                  36 months
# int_rate                                                 23.40%
# installment                                              264.65
# grade                                                         E
# sub_grade                                                    E1
# emp_title                                   Nurse Practitioner
# emp_length                                              2 years
# home_ownership                                         MORTGAGE
# annual_inc                                              70000.0
# verification_status                             Source Verified
# issue_d                                                Oct-2018
# loan_status                                             Current
# pymnt_plan                                                    n
# url                                                         NaN
# desc                                                        NaN
# purpose                                      debt_consolidation
# title                                        Debt consolidation
# zip_code                                                  441xx
# addr_state                                                   OH
# dti                                                       23.64
# delinq_2yrs                                                 0.0
# earliest_cr_line                                       Feb-1998
# inq_last_6mths                                              0.0
# mths_since_last_delinq                                      NaN
# mths_since_last_record                                      NaN
# open_acc                                                   33.0
# pub_rec                                                     0.0
# revol_bal                                               12159.0
# revol_util                                                56.8%
# total_acc                                                  55.0
# initial_list_status                                           f
# out_prncp                                               5197.21
# out_prncp_inv                                           5197.21
# total_pymnt                                             2902.31
# total_pymnt_inv                                         2902.31
# total_rec_prncp                                         1602.79
# total_rec_int                                           1299.52
# total_rec_late_fee                                          0.0
# recoveries                                                  0.0
# collection_recovery_fee                                     0.0
# last_pymnt_d                                           Sep-2019
# last_pymnt_amnt                                          264.65
# next_pymnt_d                                           Oct-2019
# last_credit_pull_d                                     Oct-2019
# collections_12_mths_ex_med                                  0.0
# mths_since_last_major_derog                                 NaN
# policy_code                                                 1.0
# application_type                                     Individual
# annual_inc_joint                                            NaN
# dti_joint                                                   NaN
# verification_status_joint                                   NaN
# acc_now_delinq                                              0.0
# tot_coll_amt                                                0.0
# tot_cur_bal                                            212938.0
# open_acc_6m                                                 1.0
# open_act_il                                                23.0
# open_il_12m                                                 0.0
# open_il_24m                                                 1.0
# mths_since_rcnt_il                                         18.0
# total_bal_il                                           200779.0
# il_util                                                   151.0
# open_rv_12m                                                 3.0
# open_rv_24m                                                 4.0
# max_bal_bc                                               3672.0
# all_util                                                  135.0
# total_rev_hi_lim                                        21400.0
# inq_fi                                                      0.0
# total_cu_tl                                                 0.0
# inq_last_12m                                                1.0
# acc_open_past_24mths                                        5.0
# avg_cur_bal                                              6453.0
# bc_open_to_buy                                           4024.0
# bc_util                                                    68.8
# chargeoff_within_12_mths                                    0.0
# delinq_amnt                                                 0.0
# mo_sin_old_il_acct                                        248.0
# mo_sin_old_rev_tl_op                                      100.0
# mo_sin_rcnt_rev_tl_op                                       2.0
# mo_sin_rcnt_tl                                              2.0
# mort_acc                                                    0.0
# mths_since_recent_bc                                        2.0
# mths_since_recent_bc_dlq                                    NaN
# mths_since_recent_inq                                       7.0
# mths_since_recent_revol_delinq                              NaN
# num_accts_ever_120_pd                                       0.0
# num_actv_bc_tl                                              4.0
# num_actv_rev_tl                                             7.0
# num_bc_sats                                                 6.0
# num_bc_tl                                                   6.0
# num_il_tl                                                  43.0
# num_op_rev_tl                                              10.0
# num_rev_accts                                              12.0
# num_rev_tl_bal_gt_0                                         7.0
# num_sats                                                   33.0
# num_tl_120dpd_2m                                            0.0
# num_tl_30dpd                                                0.0
# num_tl_90g_dpd_24m                                          0.0
# num_tl_op_past_12m                                          3.0
# pct_tl_nvr_dlq                                            100.0
# percent_bc_gt_75                                           50.0
# pub_rec_bankruptcies                                        0.0
# tax_liens                                                   0.0
# tot_hi_cred_lim                                        183197.0
# total_bal_ex_mort                                      212938.0
# total_bc_limit                                          12900.0
# total_il_high_credit_limit                             161797.0
# revol_bal_joint                                             NaN
# sec_app_earliest_cr_line                                    NaN
# sec_app_inq_last_6mths                                      NaN
# sec_app_mort_acc                                            NaN
# sec_app_open_acc                                            NaN
# sec_app_revol_util                                          NaN
# sec_app_open_act_il                                         NaN
# sec_app_num_rev_accts                                       NaN
# sec_app_chargeoff_within_12_mths                            NaN
# sec_app_collections_12_mths_ex_med                          NaN
# sec_app_mths_since_last_major_derog                         NaN
# hardship_flag                                                 N
# hardship_type                                               NaN
# hardship_reason                                             NaN
# hardship_status                                             NaN
# deferral_term                                               NaN
# hardship_amount                                             NaN
# hardship_start_date                                         NaN
# hardship_end_date                                           NaN
# payment_plan_start_date                                     NaN
# hardship_length                                             NaN
# hardship_dpd                                                NaN
# hardship_loan_status                                        NaN
# orig_projected_additional_accrued_interest                  NaN
# hardship_payoff_balance_amount                              NaN
# hardship_last_payment_amount                                NaN
# debt_settlement_flag                                          N
# debt_settlement_flag_date                                   NaN
# settlement_status                                           NaN
# settlement_date                                             NaN
# settlement_amount                                           NaN
# settlement_percentage                                       NaN
# settlement_term                                             NaN
#
#                                                             1126924  \
# id                                                              NaN
# member_id                                                       NaN
# loan_amnt                                                   15000.0
# funded_amnt                                                 15000.0
# funded_amnt_inv                                             15000.0
# term                                                      36 months
# int_rate                                                     16.14%
# installment                                                   528.4
# grade                                                             C
# sub_grade                                                        C4
# emp_title                                                   Manager
# emp_length                                                10+ years
# home_ownership                                                 RENT
# annual_inc                                                  58000.0
# verification_status                                    Not Verified
# issue_d                                                    Aug-2018
# loan_status                                                 Current
# pymnt_plan                                                        n
# url                                                             NaN
# desc                                                            NaN
# purpose                                                 credit_card
# title                                       Credit card refinancing
# zip_code                                                      445xx
# addr_state                                                       OH
# dti                                                           21.39
# delinq_2yrs                                                     0.0
# earliest_cr_line                                           Mar-2010
# inq_last_6mths                                                  0.0
# mths_since_last_delinq                                         43.0
# mths_since_last_record                                          NaN
# open_acc                                                        9.0
# pub_rec                                                         0.0
# revol_bal                                                   15226.0
# revol_util                                                    57.5%
# total_acc                                                      12.0
# initial_list_status                                               w
# out_prncp                                                  10393.38
# out_prncp_inv                                              10393.38
# total_pymnt                                                 6855.75
# total_pymnt_inv                                             6855.75
# total_rec_prncp                                             4606.62
# total_rec_int                                               2249.13
# total_rec_late_fee                                              0.0
# recoveries                                                      0.0
# collection_recovery_fee                                         0.0
# last_pymnt_d                                               Sep-2019
# last_pymnt_amnt                                               528.4
# next_pymnt_d                                               Oct-2019
# last_credit_pull_d                                         Oct-2019
# collections_12_mths_ex_med                                      0.0
# mths_since_last_major_derog                                     NaN
# policy_code                                                     1.0
# application_type                                         Individual
# annual_inc_joint                                                NaN
# dti_joint                                                       NaN
# verification_status_joint                                       NaN
# acc_now_delinq                                                  0.0
# tot_coll_amt                                                  318.0
# tot_cur_bal                                                 52583.0
# open_acc_6m                                                     1.0
# open_act_il                                                     1.0
# open_il_12m                                                     1.0
# open_il_24m                                                     2.0
# mths_since_rcnt_il                                              4.0
# total_bal_il                                                37357.0
# il_util                                                         NaN
# open_rv_12m                                                     0.0
# open_rv_24m                                                     3.0
# max_bal_bc                                                   4624.0
# all_util                                                       58.0
# total_rev_hi_lim                                            26500.0
# inq_fi                                                          0.0
# total_cu_tl                                                     0.0
# inq_last_12m                                                    2.0
# acc_open_past_24mths                                            5.0
# avg_cur_bal                                                  5843.0
# bc_open_to_buy                                               6904.0
# bc_util                                                        67.6
# chargeoff_within_12_mths                                        0.0
# delinq_amnt                                                     0.0
# mo_sin_old_il_acct                                            101.0
# mo_sin_old_rev_tl_op                                           60.0
# mo_sin_rcnt_rev_tl_op                                          13.0
# mo_sin_rcnt_tl                                                  4.0
# mort_acc                                                        0.0
# mths_since_recent_bc                                           14.0
# mths_since_recent_bc_dlq                                        NaN
# mths_since_recent_inq                                           4.0
# mths_since_recent_revol_delinq                                 43.0
# num_accts_ever_120_pd                                           0.0
# num_actv_bc_tl                                                  5.0
# num_actv_rev_tl                                                 7.0
# num_bc_sats                                                     5.0
# num_bc_tl                                                       5.0
# num_il_tl                                                       4.0
# num_op_rev_tl                                                   8.0
# num_rev_accts                                                   8.0
# num_rev_tl_bal_gt_0                                             7.0
# num_sats                                                        9.0
# num_tl_120dpd_2m                                                0.0
# num_tl_30dpd                                                    0.0
# num_tl_90g_dpd_24m                                              0.0
# num_tl_op_past_12m                                              1.0
# pct_tl_nvr_dlq                                                 91.7
# percent_bc_gt_75                                               20.0
# pub_rec_bankruptcies                                            0.0
# tax_liens                                                       0.0
# tot_hi_cred_lim                                             65389.0
# total_bal_ex_mort                                           52583.0
# total_bc_limit                                              21300.0
# total_il_high_credit_limit                                  38889.0
# revol_bal_joint                                                 NaN
# sec_app_earliest_cr_line                                        NaN
# sec_app_inq_last_6mths                                          NaN
# sec_app_mort_acc                                                NaN
# sec_app_open_acc                                                NaN
# sec_app_revol_util                                              NaN
# sec_app_open_act_il                                             NaN
# sec_app_num_rev_accts                                           NaN
# sec_app_chargeoff_within_12_mths                                NaN
# sec_app_collections_12_mths_ex_med                              NaN
# sec_app_mths_since_last_major_derog                             NaN
# hardship_flag                                                     N
# hardship_type                                                   NaN
# hardship_reason                                                 NaN
# hardship_status                                                 NaN
# deferral_term                                                   NaN
# hardship_amount                                                 NaN
# hardship_start_date                                             NaN
# hardship_end_date                                               NaN
# payment_plan_start_date                                         NaN
# hardship_length                                                 NaN
# hardship_dpd                                                    NaN
# hardship_loan_status                                            NaN
# orig_projected_additional_accrued_interest                      NaN
# hardship_payoff_balance_amount                                  NaN
# hardship_last_payment_amount                                    NaN
# debt_settlement_flag                                              N
# debt_settlement_flag_date                                       NaN
# settlement_status                                               NaN
# settlement_date                                                 NaN
# settlement_amount                                               NaN
# settlement_percentage                                           NaN
# settlement_term                                                 NaN
#
#                                                     703596            1079064  \
# id                                                      NaN               NaN
# member_id                                               NaN               NaN
# loan_amnt                                            5000.0           30000.0
# funded_amnt                                          5000.0           30000.0
# funded_amnt_inv                                      5000.0           30000.0
# term                                              36 months         60 months
# int_rate                                             11.39%            13.56%
# installment                                          164.62            691.23
# grade                                                     B                 C
# sub_grade                                                B3                C1
# emp_title                                     HR Generalist  Home health care
# emp_length                                        10+ years           4 years
# home_ownership                                     MORTGAGE              RENT
# annual_inc                                          65000.0           75000.0
# verification_status                         Source Verified   Source Verified
# issue_d                                            Jan-2017          Sep-2018
# loan_status                                      Fully Paid           Current
# pymnt_plan                                                n                 n
# url                                                     NaN               NaN
# desc                                                    NaN               NaN
# purpose                                            vacation    major_purchase
# title                                              Vacation    Major purchase
# zip_code                                              559xx             117xx
# addr_state                                               MN                NY
# dti                                                   30.91             17.79
# delinq_2yrs                                             0.0               0.0
# earliest_cr_line                                   Mar-1996          Dec-2012
# inq_last_6mths                                          0.0               1.0
# mths_since_last_delinq                                  NaN               NaN
# mths_since_last_record                                  NaN               NaN
# open_acc                                               21.0              26.0
# pub_rec                                                 0.0               0.0
# revol_bal                                           17933.0            2775.0
# revol_util                                            28.2%              8.7%
# total_acc                                              54.0              35.0
# initial_list_status                                       f                 w
# out_prncp                                               0.0           25500.4
# out_prncp_inv                                           0.0           25500.4
# total_pymnt                                     5241.014657           8272.16
# total_pymnt_inv                                     5241.01           8272.16
# total_rec_prncp                                      5000.0            4499.6
# total_rec_int                                        241.01           3772.56
# total_rec_late_fee                                      0.0               0.0
# recoveries                                              0.0               0.0
# collection_recovery_fee                                 0.0               0.0
# last_pymnt_d                                       Jun-2017          Sep-2019
# last_pymnt_amnt                                     4585.69            691.23
# next_pymnt_d                                            NaN          Oct-2019
# last_credit_pull_d                                 Jul-2017          Oct-2019
# collections_12_mths_ex_med                              0.0               0.0
# mths_since_last_major_derog                             NaN               NaN
# policy_code                                             1.0               1.0
# application_type                                 Individual        Individual
# annual_inc_joint                                        NaN               NaN
# dti_joint                                               NaN               NaN
# verification_status_joint                               NaN               NaN
# acc_now_delinq                                          0.0               0.0
# tot_coll_amt                                            0.0               0.0
# tot_cur_bal                                        209990.0           28557.0
# open_acc_6m                                             1.0               0.0
# open_act_il                                             3.0               3.0
# open_il_12m                                             2.0               2.0
# open_il_24m                                             6.0               2.0
# mths_since_rcnt_il                                      4.0               7.0
# total_bal_il                                       120621.0           25782.0
# il_util                                                95.0              75.0
# open_rv_12m                                             0.0               3.0
# open_rv_24m                                             0.0               7.0
# max_bal_bc                                          11775.0             130.0
# all_util                                               55.0              43.0
# total_rev_hi_lim                                    63500.0           31900.0
# inq_fi                                                  1.0               4.0
# total_cu_tl                                             7.0               5.0
# inq_last_12m                                            2.0               9.0
# acc_open_past_24mths                                    7.0               9.0
# avg_cur_bal                                         12352.0            1098.0
# bc_open_to_buy                                      20470.0           18372.0
# bc_util                                                46.6               1.2
# chargeoff_within_12_mths                                0.0               0.0
# delinq_amnt                                             0.0               0.0
# mo_sin_old_il_acct                                    153.0              60.0
# mo_sin_old_rev_tl_op                                  250.0              69.0
# mo_sin_rcnt_rev_tl_op                                  29.0               7.0
# mo_sin_rcnt_tl                                          4.0               7.0
# mort_acc                                                1.0               0.0
# mths_since_recent_bc                                   29.0               7.0
# mths_since_recent_bc_dlq                                NaN               NaN
# mths_since_recent_inq                                  11.0               0.0
# mths_since_recent_revol_delinq                          NaN               NaN
# num_accts_ever_120_pd                                   0.0               0.0
# num_actv_bc_tl                                          2.0               7.0
# num_actv_rev_tl                                         3.0               8.0
# num_bc_sats                                             6.0              13.0
# num_bc_tl                                              14.0              15.0
# num_il_tl                                              24.0               6.0
# num_op_rev_tl                                          17.0              23.0
# num_rev_accts                                          29.0              29.0
# num_rev_tl_bal_gt_0                                     3.0               8.0
# num_sats                                               21.0              26.0
# num_tl_120dpd_2m                                        0.0               0.0
# num_tl_30dpd                                            0.0               0.0
# num_tl_90g_dpd_24m                                      0.0               0.0
# num_tl_op_past_12m                                      2.0               5.0
# pct_tl_nvr_dlq                                        100.0             100.0
# percent_bc_gt_75                                       16.7               0.0
# pub_rec_bankruptcies                                    0.0               0.0
# tax_liens                                               0.0               0.0
# tot_hi_cred_lim                                    259149.0           66452.0
# total_bal_ex_mort                                  138554.0           28557.0
# total_bc_limit                                      38300.0           18600.0
# total_il_high_credit_limit                         122649.0           34552.0
# revol_bal_joint                                         NaN               NaN
# sec_app_earliest_cr_line                                NaN               NaN
# sec_app_inq_last_6mths                                  NaN               NaN
# sec_app_mort_acc                                        NaN               NaN
# sec_app_open_acc                                        NaN               NaN
# sec_app_revol_util                                      NaN               NaN
# sec_app_open_act_il                                     NaN               NaN
# sec_app_num_rev_accts                                   NaN               NaN
# sec_app_chargeoff_within_12_mths                        NaN               NaN
# sec_app_collections_12_mths_ex_med                      NaN               NaN
# sec_app_mths_since_last_major_derog                     NaN               NaN
# hardship_flag                                             N                 N
# hardship_type                                           NaN               NaN
# hardship_reason                                         NaN               NaN
# hardship_status                                         NaN               NaN
# deferral_term                                           NaN               NaN
# hardship_amount                                         NaN               NaN
# hardship_start_date                                     NaN               NaN
# hardship_end_date                                       NaN               NaN
# payment_plan_start_date                                 NaN               NaN
# hardship_length                                         NaN               NaN
# hardship_dpd                                            NaN               NaN
# hardship_loan_status                                    NaN               NaN
# orig_projected_additional_accrued_interest              NaN               NaN
# hardship_payoff_balance_amount                          NaN               NaN
# hardship_last_payment_amount                            NaN               NaN
# debt_settlement_flag                                      N                 N
# debt_settlement_flag_date                               NaN               NaN
# settlement_status                                       NaN               NaN
# settlement_date                                         NaN               NaN
# settlement_amount                                       NaN               NaN
# settlement_percentage                                   NaN               NaN
# settlement_term                                         NaN               NaN
#
#                                                        647293
# id                                                         NaN
# member_id                                                  NaN
# loan_amnt                                               7500.0
# funded_amnt                                             7500.0
# funded_amnt_inv                                         7500.0
# term                                                 36 months
# int_rate                                                12.74%
# installment                                             251.77
# grade                                                        C
# sub_grade                                                   C1
# emp_title                                                  NaN
# emp_length                                                 NaN
# home_ownership                                            RENT
# annual_inc                                             65000.0
# verification_status                            Source Verified
# issue_d                                               Mar-2017
# loan_status                                         Fully Paid
# pymnt_plan                                                   n
# url                                                        NaN
# desc                                                       NaN
# purpose                                     debt_consolidation
# title                                       Debt consolidation
# zip_code                                                 313xx
# addr_state                                                  GA
# dti                                                        3.6
# delinq_2yrs                                                0.0
# earliest_cr_line                                      Oct-1994
# inq_last_6mths                                             0.0
# mths_since_last_delinq                                    63.0
# mths_since_last_record                                     NaN
# open_acc                                                   6.0
# pub_rec                                                    0.0
# revol_bal                                               7680.0
# revol_util                                               52.6%
# total_acc                                                 10.0
# initial_list_status                                          f
# out_prncp                                                  0.0
# out_prncp_inv                                              0.0
# total_pymnt                                         8280.40736
# total_pymnt_inv                                        8280.41
# total_rec_prncp                                         7500.0
# total_rec_int                                           780.41
# total_rec_late_fee                                         0.0
# recoveries                                                 0.0
# collection_recovery_fee                                    0.0
# last_pymnt_d                                          Feb-2018
# last_pymnt_amnt                                        5768.02
# next_pymnt_d                                               NaN
# last_credit_pull_d                                    Feb-2018
# collections_12_mths_ex_med                                 0.0
# mths_since_last_major_derog                                NaN
# policy_code                                                1.0
# application_type                                    Individual
# annual_inc_joint                                           NaN
# dti_joint                                                  NaN
# verification_status_joint                                  NaN
# acc_now_delinq                                             0.0
# tot_coll_amt                                               0.0
# tot_cur_bal                                             7680.0
# open_acc_6m                                                2.0
# open_act_il                                                0.0
# open_il_12m                                                0.0
# open_il_24m                                                0.0
# mths_since_rcnt_il                                       137.0
# total_bal_il                                               0.0
# il_util                                                    NaN
# open_rv_12m                                                2.0
# open_rv_24m                                                2.0
# max_bal_bc                                              2940.0
# all_util                                                  53.0
# total_rev_hi_lim                                       14600.0
# inq_fi                                                     0.0
# total_cu_tl                                                0.0
# inq_last_12m                                               0.0
# acc_open_past_24mths                                       2.0
# avg_cur_bal                                             1536.0
# bc_open_to_buy                                          5920.0
# bc_util                                                   48.1
# chargeoff_within_12_mths                                   0.0
# delinq_amnt                                                0.0
# mo_sin_old_il_acct                                       137.0
# mo_sin_old_rev_tl_op                                     269.0
# mo_sin_rcnt_rev_tl_op                                      5.0
# mo_sin_rcnt_tl                                             5.0
# mort_acc                                                   0.0
# mths_since_recent_bc                                     108.0
# mths_since_recent_bc_dlq                                   NaN
# mths_since_recent_inq                                      NaN
# mths_since_recent_revol_delinq                             NaN
# num_accts_ever_120_pd                                      0.0
# num_actv_bc_tl                                             3.0
# num_actv_rev_tl                                            4.0
# num_bc_sats                                                4.0
# num_bc_tl                                                  6.0
# num_il_tl                                                  1.0
# num_op_rev_tl                                              6.0
# num_rev_accts                                              9.0
# num_rev_tl_bal_gt_0                                        4.0
# num_sats                                                   6.0
# num_tl_120dpd_2m                                           0.0
# num_tl_30dpd                                               0.0
# num_tl_90g_dpd_24m                                         0.0
# num_tl_op_past_12m                                         2.0
# pct_tl_nvr_dlq                                            90.0
# percent_bc_gt_75                                           0.0
# pub_rec_bankruptcies                                       0.0
# tax_liens                                                  0.0
# tot_hi_cred_lim                                        14600.0
# total_bal_ex_mort                                       7680.0
# total_bc_limit                                         11400.0
# total_il_high_credit_limit                                 0.0
# revol_bal_joint                                            NaN
# sec_app_earliest_cr_line                                   NaN
# sec_app_inq_last_6mths                                     NaN
# sec_app_mort_acc                                           NaN
# sec_app_open_acc                                           NaN
# sec_app_revol_util                                         NaN
# sec_app_open_act_il                                        NaN
# sec_app_num_rev_accts                                      NaN
# sec_app_chargeoff_within_12_mths                           NaN
# sec_app_collections_12_mths_ex_med                         NaN
# sec_app_mths_since_last_major_derog                        NaN
# hardship_flag                                                N
# hardship_type                                              NaN
# hardship_reason                                            NaN
# hardship_status                                            NaN
# deferral_term                                              NaN
# hardship_amount                                            NaN
# hardship_start_date                                        NaN
# hardship_end_date                                          NaN
# payment_plan_start_date                                    NaN
# hardship_length                                            NaN
# hardship_dpd                                               NaN
# hardship_loan_status                                       NaN
# orig_projected_additional_accrued_interest                 NaN
# hardship_payoff_balance_amount                             NaN
# hardship_last_payment_amount                               NaN
# debt_settlement_flag                                         N
# debt_settlement_flag_date                                  NaN
# settlement_status                                          NaN
# settlement_date                                            NaN
# settlement_amount                                          NaN
# settlement_percentage                                      NaN
# settlement_term                                            NaN

# %%
## แสดงจำนวนของค่าที่แตกต่างกันใน loan_status โดยนับ null ด้วย

loans['loan_status'].value_counts(dropna=False)
# Out:
# Current               663690
# Fully Paid            583755
# Charged Off           152999
# Late (31-120 days)     19455
# In Grace Period         6136
# Late (16-30 days)       4986
# Default                 1419
# NaN                       26
# Name: loan_status, dtype: int64

# %%
## เลือกเฉพาะ rows ข้อมูลที่มี loan_staus เป็น Fully Paid และ Charged Off

loans = loans[loans['loan_status'].isin(['Fully Paid', 'Charged Off'])]

# %%
## แสดงจำนวนของค่าที่แตกต่างกันใน loan_status โดยไม่นับ null ด้วย
loans['loan_status'].value_counts()

### จากผลการวิเคราะห์ สรุปได้ว่ามี imbalance classes
# Out:
# Fully Paid     583755
# Charged Off    152999
# Name: loan_status, dtype: int64

# %%
## ดูจำนวน row และจำนวน columns ของข้อมูลหลังจากเลือกมาเฉพาะ Fully Paid กับ Charge Off

loans.shape
# Out:
# (736754, 144)

# %%
## ประกาศตัวแปร

nullCols_list = []
outlierCols_list = []
highScaleCols_list = []
highDispersionCols_list = []
highCorrCols_list = []
lowCorrCols_list = []
numCol_list = []
catCol_list = []

## รายชื่อ Columns ที่ไม่เกี่ยวข้องกับการวิเคราะห์ฯ ซึ่งได้จากการสอบถามผู้เชี่ยวชาญทางธุรกิจ 
## (Requirement from business perspective)

temp_IgnoredCols_list = ['total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
       'collection_recovery_fee', 'last_pymnt_amnt',
       'collections_12_mths_ex_med', 'policy_code', 'acc_now_delinq',
       'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il',
       'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il',
       'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
       'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
       'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
       'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
       'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
       'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
       'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
       'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
       'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
       'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
       'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
       'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
       'total_il_high_credit_limit'\
       'delinq_2yrs', 'inq_last_6mths','out_prncp', 'out_prncp_inv','total_il_high_credit_limit'
       ]

# %% [markdown]
# ## **2.1 Null and Dispersion Profiling with Univariate Analysis**

# %%
loans.isnull().any()
# Out:
# id                                             True
# member_id                                      True
# loan_amnt                                     False
# funded_amnt                                   False
# funded_amnt_inv                               False
# term                                          False
# int_rate                                      False
# installment                                   False
# grade                                         False
# sub_grade                                     False
# emp_title                                      True
# emp_length                                     True
# home_ownership                                False
# annual_inc                                    False
# verification_status                           False
# issue_d                                       False
# loan_status                                   False
# pymnt_plan                                    False
# url                                            True
# desc                                           True
# purpose                                       False
# title                                          True
# zip_code                                       True
# addr_state                                    False
# dti                                            True
# delinq_2yrs                                   False
# earliest_cr_line                              False
# inq_last_6mths                                 True
# mths_since_last_delinq                         True
# mths_since_last_record                         True
# open_acc                                      False
# pub_rec                                       False
# revol_bal                                     False
# revol_util                                     True
# total_acc                                     False
# initial_list_status                           False
# out_prncp                                     False
# out_prncp_inv                                 False
# total_pymnt                                   False
# total_pymnt_inv                               False
# total_rec_prncp                               False
# total_rec_int                                 False
# total_rec_late_fee                            False
# recoveries                                    False
# collection_recovery_fee                       False
# last_pymnt_d                                   True
# last_pymnt_amnt                               False
# next_pymnt_d                                   True
# last_credit_pull_d                             True
# collections_12_mths_ex_med                    False
# mths_since_last_major_derog                    True
# policy_code                                   False
# application_type                              False
# annual_inc_joint                               True
# dti_joint                                      True
# verification_status_joint                      True
# acc_now_delinq                                False
# tot_coll_amt                                  False
# tot_cur_bal                                   False
# open_acc_6m                                    True
# open_act_il                                    True
# open_il_12m                                    True
# open_il_24m                                    True
# mths_since_rcnt_il                             True
# total_bal_il                                   True
# il_util                                        True
# open_rv_12m                                    True
# open_rv_24m                                    True
# max_bal_bc                                     True
# all_util                                       True
# total_rev_hi_lim                              False
# inq_fi                                         True
# total_cu_tl                                    True
# inq_last_12m                                   True
# acc_open_past_24mths                          False
# avg_cur_bal                                    True
# bc_open_to_buy                                 True
# bc_util                                        True
# chargeoff_within_12_mths                      False
# delinq_amnt                                   False
# mo_sin_old_il_acct                             True
# mo_sin_old_rev_tl_op                          False
# mo_sin_rcnt_rev_tl_op                         False
# mo_sin_rcnt_tl                                False
# mort_acc                                      False
# mths_since_recent_bc                           True
# mths_since_recent_bc_dlq                       True
# mths_since_recent_inq                          True
# mths_since_recent_revol_delinq                 True
# num_accts_ever_120_pd                         False
# num_actv_bc_tl                                False
# num_actv_rev_tl                               False
# num_bc_sats                                   False
# num_bc_tl                                     False
# num_il_tl                                     False
# num_op_rev_tl                                 False
# num_rev_accts                                 False
# num_rev_tl_bal_gt_0                           False
# num_sats                                      False
# num_tl_120dpd_2m                               True
# num_tl_30dpd                                  False
# num_tl_90g_dpd_24m                            False
# num_tl_op_past_12m                            False
# pct_tl_nvr_dlq                                 True
# percent_bc_gt_75                               True
# pub_rec_bankruptcies                          False
# tax_liens                                     False
# tot_hi_cred_lim                               False
# total_bal_ex_mort                             False
# total_bc_limit                                False
# total_il_high_credit_limit                    False
# revol_bal_joint                                True
# sec_app_earliest_cr_line                       True
# sec_app_inq_last_6mths                         True
# sec_app_mort_acc                               True
# sec_app_open_acc                               True
# sec_app_revol_util                             True
# sec_app_open_act_il                            True
# sec_app_num_rev_accts                          True
# sec_app_chargeoff_within_12_mths               True
# sec_app_collections_12_mths_ex_med             True
# sec_app_mths_since_last_major_derog            True
# hardship_flag                                 False
# hardship_type                                  True
# hardship_reason                                True
# hardship_status                                True
# deferral_term                                  True
# hardship_amount                                True
# hardship_start_date                            True
# hardship_end_date                              True
# payment_plan_start_date                        True
# hardship_length                                True
# hardship_dpd                                   True
# hardship_loan_status                           True
# orig_projected_additional_accrued_interest     True
# hardship_payoff_balance_amount                 True
# hardship_last_payment_amount                   True
# debt_settlement_flag                          False
# debt_settlement_flag_date                      True
# settlement_status                              True
# settlement_date                                True
# settlement_amount                              True
# settlement_percentage                          True
# settlement_term                                True
# dtype: bool

# %%
## แสดงจำนวนของค่าที่แตกต่างกันใน loan_status โดยนับ null ด้วย
### loans['loan_status'].value_counts(dropna=False)

# %%
## คำนวณ percentage ของ null ในแต่ละ column

missing_fractions = loans.isnull().mean().sort_values(ascending=False)

# %%
## แสดงผลการคำนวณ percentage ของ null ในแต่ละ column
missing_fractions.head(100)
# Out:
# id                                            1.000000
# next_pymnt_d                                  1.000000
# url                                           1.000000
# member_id                                     1.000000
# desc                                          0.999974
# orig_projected_additional_accrued_interest    0.994470
# payment_plan_start_date                       0.991767
# hardship_type                                 0.991767
# hardship_reason                               0.991767
# hardship_status                               0.991767
# hardship_amount                               0.991767
# hardship_start_date                           0.991767
# hardship_end_date                             0.991767
# deferral_term                                 0.991767
# hardship_length                               0.991767
# hardship_loan_status                          0.991767
# hardship_payoff_balance_amount                0.991767
# hardship_last_payment_amount                  0.991767
# hardship_dpd                                  0.991767
# sec_app_mths_since_last_major_derog           0.991228
# sec_app_revol_util                            0.974397
# sec_app_open_act_il                           0.973970
# revol_bal_joint                               0.973970
# sec_app_earliest_cr_line                      0.973970
# sec_app_inq_last_6mths                        0.973970
# sec_app_mort_acc                              0.973970
# sec_app_open_acc                              0.973970
# sec_app_collections_12_mths_ex_med            0.973970
# sec_app_num_rev_accts                         0.973970
# sec_app_chargeoff_within_12_mths              0.973970
# debt_settlement_flag_date                     0.966861
# settlement_status                             0.966861
# settlement_percentage                         0.966861
# settlement_amount                             0.966861
# settlement_date                               0.966861
# settlement_term                               0.966861
# verification_status_joint                     0.955839
# dti_joint                                     0.954802
# annual_inc_joint                              0.954799
# mths_since_last_record                        0.808157
# mths_since_recent_bc_dlq                      0.757971
# mths_since_last_major_derog                   0.720228
# mths_since_recent_revol_delinq                0.654341
# mths_since_last_delinq                        0.490307
# il_util                                       0.136979
# mths_since_recent_inq                         0.098175
# emp_title                                     0.074375
# emp_length                                    0.070778
# num_tl_120dpd_2m                              0.044199
# title                                         0.027922
# mths_since_rcnt_il                            0.027449
# mo_sin_old_il_acct                            0.027380
# bc_util                                       0.012066
# percent_bc_gt_75                              0.011575
# bc_open_to_buy                                0.011537
# mths_since_recent_bc                          0.010882
# last_pymnt_d                                  0.002466
# revol_util                                    0.000713
# dti                                           0.000641
# all_util                                      0.000149
# inq_last_12m                                  0.000077
# total_cu_tl                                   0.000077
# open_acc_6m                                   0.000077
# open_il_24m                                   0.000076
# total_bal_il                                  0.000076
# open_act_il                                   0.000076
# open_rv_12m                                   0.000076
# open_rv_24m                                   0.000076
# max_bal_bc                                    0.000076
# open_il_12m                                   0.000076
# inq_fi                                        0.000076
# last_credit_pull_d                            0.000022
# avg_cur_bal                                   0.000014
# zip_code                                      0.000005
# pct_tl_nvr_dlq                                0.000001
# inq_last_6mths                                0.000001
# tot_hi_cred_lim                               0.000000
# total_bal_ex_mort                             0.000000
# earliest_cr_line                              0.000000
# loan_amnt                                     0.000000
# total_bc_limit                                0.000000
# total_il_high_credit_limit                    0.000000
# tax_liens                                     0.000000
# funded_amnt                                   0.000000
# revol_bal                                     0.000000
# pub_rec                                       0.000000
# open_acc                                      0.000000
# funded_amnt_inv                               0.000000
# term                                          0.000000
# sub_grade                                     0.000000
# int_rate                                      0.000000
# debt_settlement_flag                          0.000000
# installment                                   0.000000
# grade                                         0.000000
# delinq_2yrs                                   0.000000
# addr_state                                    0.000000
# hardship_flag                                 0.000000
# home_ownership                                0.000000
# annual_inc                                    0.000000
# verification_status                           0.000000
# dtype: float64

# %%
#loans.isnull().sum().sort_values(ascending=False)

# %%
nullCols_list = missing_fractions[missing_fractions > 0.4].index.tolist()
sorted(nullCols_list)
# Out:
# ['annual_inc_joint',
#  'debt_settlement_flag_date',
#  'deferral_term',
#  'desc',
#  'dti_joint',
#  'hardship_amount',
#  'hardship_dpd',
#  'hardship_end_date',
#  'hardship_last_payment_amount',
#  'hardship_length',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_reason',
#  'hardship_start_date',
#  'hardship_status',
#  'hardship_type',
#  'id',
#  'member_id',
#  'mths_since_last_delinq',
#  'mths_since_last_major_derog',
#  'mths_since_last_record',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_revol_delinq',
#  'next_pymnt_d',
#  'orig_projected_additional_accrued_interest',
#  'payment_plan_start_date',
#  'revol_bal_joint',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_mths_since_last_major_derog',
#  'sec_app_num_rev_accts',
#  'sec_app_open_acc',
#  'sec_app_open_act_il',
#  'sec_app_revol_util',
#  'settlement_amount',
#  'settlement_date',
#  'settlement_percentage',
#  'settlement_status',
#  'settlement_term',
#  'url',
#  'verification_status_joint']

# %%
# เลือกชื่อ Columns ที่ไม่ได้อยู่ใน nullCols_list และไม่ได้อยู่ใน temp_IgnoredCols_list

selectedCols_list = [x for x in loans.columns if ((x not in nullCols_list)&(x not in temp_IgnoredCols_list))]


loans = loans[selectedCols_list]

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 736754 entries, 0 to 1432462
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             736754 non-null  float64
#  1   funded_amnt           736754 non-null  float64
#  2   funded_amnt_inv       736754 non-null  float64
#  3   term                  736754 non-null  object
#  4   int_rate              736754 non-null  object
#  5   installment           736754 non-null  float64
#  6   grade                 736754 non-null  object
#  7   sub_grade             736754 non-null  object
#  8   emp_title             681958 non-null  object
#  9   emp_length            684608 non-null  object
#  10  home_ownership        736754 non-null  object
#  11  annual_inc            736754 non-null  float64
#  12  verification_status   736754 non-null  object
#  13  issue_d               736754 non-null  object
#  14  loan_status           736754 non-null  object
#  15  pymnt_plan            736754 non-null  object
#  16  purpose               736754 non-null  object
#  17  title                 716182 non-null  object
#  18  zip_code              736750 non-null  object
#  19  addr_state            736754 non-null  object
#  20  dti                   736282 non-null  float64
#  21  delinq_2yrs           736754 non-null  float64
#  22  earliest_cr_line      736754 non-null  object
#  23  open_acc              736754 non-null  float64
#  24  pub_rec               736754 non-null  float64
#  25  revol_bal             736754 non-null  float64
#  26  revol_util            736229 non-null  object
#  27  total_acc             736754 non-null  float64
#  28  initial_list_status   736754 non-null  object
#  29  total_pymnt           736754 non-null  float64
#  30  total_pymnt_inv       736754 non-null  float64
#  31  last_pymnt_d          734937 non-null  object
#  32  last_credit_pull_d    736738 non-null  object
#  33  application_type      736754 non-null  object
#  34  hardship_flag         736754 non-null  object
#  35  debt_settlement_flag  736754 non-null  object
# dtypes: float64(13), object(23)
# memory usage: 208.0+ MB

# %% [markdown]
# ***----------สิ่งที่ได้รับตอนนี้ คือ Dataframe มีขนาดเล็กลง (Smaller Feature Space และข้อมูลเกี่ยวข้องกับการวิเคราะห์ข้อมูลมากขึ้น (Relevance)----------***

# %%
null_series = loans.isnull().any()

# %%
nullCols_list
# Out:
# ['id',
#  'next_pymnt_d',
#  'url',
#  'member_id',
#  'desc',
#  'orig_projected_additional_accrued_interest',
#  'payment_plan_start_date',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'deferral_term',
#  'hardship_length',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'hardship_dpd',
#  'sec_app_mths_since_last_major_derog',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_percentage',
#  'settlement_amount',
#  'settlement_date',
#  'settlement_term',
#  'verification_status_joint',
#  'dti_joint',
#  'annual_inc_joint',
#  'mths_since_last_record',
#  'mths_since_recent_bc_dlq',
#  'mths_since_last_major_derog',
#  'mths_since_recent_revol_delinq',
#  'mths_since_last_delinq']

# %%
nullCols_list = null_series[null_series].index.tolist()

# %%
nullCols_list
# Out:
# ['emp_title',
#  'emp_length',
#  'title',
#  'zip_code',
#  'dti',
#  'revol_util',
#  'last_pymnt_d',
#  'last_credit_pull_d']

# %% [markdown]
# ***----------สิ่งที่ได้รับตอนนี้ คือ ชื่อ Columns ที่มี Null Profile----------***

# %%
# เลือกชื่อ Columns ที่เป็น Numerical Variables

numCol_list = loans.select_dtypes('number').columns

# %%
# คำนวณค่าสถิติจาก Columns ที่เป็น Numerical

loans[numCol_list].describe().transpose()
# Out:
#                     count          mean           std      min           25%  \
# loan_amnt        736754.0  14504.612089   9243.765872  1000.00   7200.000000
# funded_amnt      736754.0  14504.587657   9243.765737  1000.00   7200.000000
# funded_amnt_inv  736754.0  14499.239053   9241.323685   725.00   7200.000000
# installment      736754.0    446.576084    282.946410    30.12    238.110000
# annual_inc       736754.0  79498.492644  78094.751870     0.00  48000.000000
# dti              736282.0     18.711086     13.794251    -1.00     11.890000
# delinq_2yrs      736754.0      0.327729      0.900894     0.00      0.000000
# open_acc         736754.0     11.757615      5.773028     0.00      8.000000
# pub_rec          736754.0      0.247868      0.664559     0.00      0.000000
# revol_bal        736754.0  16101.814410  22819.350827     0.00   5628.000000
# total_acc        736754.0     24.403398     12.166020     2.00     16.000000
# total_pymnt      736754.0  14307.429253  10419.139766     0.00   6321.638445
# total_pymnt_inv  736754.0  14302.056976  10416.148367     0.00   6318.660000
#
#                           50%           75%           max
# loan_amnt        12000.000000  20000.000000  4.000000e+04
# funded_amnt      12000.000000  20000.000000  4.000000e+04
# funded_amnt_inv  12000.000000  20000.000000  4.000000e+04
# installment        370.480000    602.300000  1.715420e+03
# annual_inc       67000.000000  95000.000000  9.573072e+06
# dti                 17.820000     24.500000  9.990000e+02
# delinq_2yrs          0.000000      0.000000  2.900000e+01
# open_acc            11.000000     15.000000  8.600000e+01
# pub_rec              0.000000      0.000000  6.100000e+01
# revol_bal        10694.000000  19172.000000  1.137891e+06
# total_acc           23.000000     31.000000  1.760000e+02
# total_pymnt      11395.679733  19879.879549  6.450823e+04
# total_pymnt_inv  11390.625000  19870.345000  6.450823e+04

# %%
# เลือกชื่อ Columns ที่เป็น categorical variables (String)

catCol_list = loans.select_dtypes('object').columns

# %%
# คำนวณค่าสถิติจาก Columns ที่เป็น String

loans[catCol_list].describe().transpose()
# Out:
#                        count  unique                 top    freq
# term                  736754       2           36 months  580853
# int_rate              736754     258              11.49%   33561
# grade                 736754       7                   C  222414
# sub_grade             736754      35                  B5   54266
# emp_title             681958  144235             Teacher   13298
# emp_length            684608      11           10+ years  247496
# home_ownership        736754       5            MORTGAGE  361978
# verification_status   736754       3     Source Verified  306372
# issue_d               736754      30            Mar-2017   86864
# loan_status           736754       2          Fully Paid  583755
# pymnt_plan            736754       1                   n  736754
# purpose               736754      13  debt_consolidation  415727
# title                 716182      13  Debt consolidation  403059
# zip_code              736750     911               750xx    7936
# addr_state            736754      50                  CA  103376
# earliest_cr_line      736754     707            Sep-2004    5809
# revol_util            736229    1188                  0%    4681
# initial_list_status   736754       2                   w  554970
# last_pymnt_d          734937      46            Apr-2019   36386
# last_credit_pull_d    736738      47            Oct-2019  254174
# application_type      736754       2          Individual  703452
# hardship_flag         736754       1                   N  736754
# debt_settlement_flag  736754       2                   N  712339

# %%
highCardinality_list = ['emp_title','revol_util','earliest_cr_line','zip_code']

# %%
loans['emp_length'].value_counts()
# Out:
# 10+ years    247496
# 2 years       68493
# 3 years       60901
# < 1 year      55912
# 1 year        49886
# 5 years       45876
# 4 years       44489
# 6 years       32116
# 8 years       28125
# 9 years       26475
# 7 years       24839
# Name: emp_length, dtype: int64

# %%
## คำนวนค่า Coefficient of Variance เพื่อดูว่า Columns ไหน Dispersion มากน้อยกว่ากัน

describe_pd = loans[numCol_list].describe().transpose()

describe_pd.assign(cv=lambda x: ((100/x['mean'])*x['std']))[['cv','mean','std']].sort_values('cv',ascending=False)
# Out:
#                          cv          mean           std
# delinq_2yrs      274.889447      0.327729      0.900894
# pub_rec          268.109730      0.247868      0.664559
# revol_bal        141.719127  16101.814410  22819.350827
# annual_inc        98.234255  79498.492644  78094.751870
# dti               73.722342     18.711086     13.794251
# total_pymnt_inv   72.829722  14302.056976  10416.148367
# total_pymnt       72.823283  14307.429253  10419.139766
# funded_amnt_inv   63.736612  14499.239053   9241.323685
# funded_amnt       63.729945  14504.587657   9243.765737
# loan_amnt         63.729839  14504.612089   9243.765872
# installment       63.359060    446.576084    282.946410
# total_acc         49.853797     24.403398     12.166020
# open_acc          49.100332     11.757615      5.773028

# %%
highDispersionCols_list.append('delinq_2yrs')

# %%
highDispersionCols_list.append('pub_rec')

# %%
highDispersionCols_list.append('revol_bal')

# %%
highDispersionCols_list
# Out:
# ['delinq_2yrs', 'pub_rec', 'revol_bal']

# %% [markdown]
# ***----------สิ่งที่ได้รับตอนนี้ คือ ชื่อ Columns ที่มี High Dispersion Profile----------***

# %% [markdown]
# ## **2.2 Outlier and Correlation Profling with Multivariate Analysis**

# %%
def plot_var(arg_df, col_name, full_name, continuous):
    """
    Visualize a variable with and without faceting on the loan status.
    - col_name is the variable name in the dataframe
    - full_name is the full variable name
    - continuous is True if the variable is continuous, False otherwise
    """
    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
    
    # Plot without loan status
    if continuous:
        sns.distplot(arg_df.loc[arg_df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(arg_df[col_name], order=sorted(arg_df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(full_name)
    ax1.set_ylabel('Count')
    ax1.set_title(full_name)

    # Plot with loan status
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=arg_df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
    else:
        charge_off_rates = arg_df.groupby(col_name)['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
        sns.barplot(x=charge_off_rates.index, y=charge_off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of arg_df Charged-off')
        ax2.set_title('Charge-off Rate by ' + full_name)
    ax2.set_xlabel(full_name)
    
    plt.tight_layout()

# %% [markdown]
# ### **2.2.1 Loan Amount**

# %%
plot_var(loans,'loan_amnt', 'Loan Amount', continuous=True)

### จากผลการวิเคราะห์ด้วย BoxPlot พบว่า Loan Amount ของ Fully Paid และ Charged Off มี median ต่างกันพอสมควร โดย Charged Off มี median ของ Loan Amount ที่สูงกว่ามาก
### ดังนี้แล้วจึงแปรผลได้ว่า การปล่อยกู้ในวงเงินที่สูงขึ้น มีความสัมพันธ์กับ การไม่ชำระเงินคืนอย่างมาก
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## ขยายรายละเอียดจาก boxplot ข้างบน

loans.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off  152999.0  15848.418127  9336.441359  1000.0  8550.0  14400.0
# Fully Paid   583755.0  14152.407859  9186.876762  1000.0  7000.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  21000.0  40000.0
# Fully Paid   20000.0  40000.0

# %% [markdown]
# ### **2.2.2 Interest Rate**

# %%
## ลบเครื่องหมาย % ออกจากค่าใน int_rate แล้วเปลี่ยน data type ของ int_rate เป็น float64

loans['int_rate'] = loans[['int_rate']].apply(lambda x: x.replace(regex=['%'],value=''))\
.astype('float64')

# %%
loans['int_rate'].describe()
# Out:
# count    736754.000000
# mean         13.210859
# std           5.158126
# min           5.310000
# 25%           9.490000
# 50%          12.740000
# 75%          15.990000
# max          30.990000
# Name: int_rate, dtype: float64

# %%
plot_var(loans,'int_rate', 'Interest Rate', continuous=True)

### จากผลการวิเคราะห์ด้วย BoxPlot พบว่า Interest Rate ของ Fully Paid กับ Charged Off มี meean ของ Interest Rate ที่ต่างกันเล็กน้อย
### ดังนี้แล้วจึงแปรผลได้ว่า ดอกเบี้ยเงินกู้ที่แตกต่างกัน มีความสัมพันธ์เกี่ยวข้องกับ การชำระหนี้คืนทั้งหมด หรือไม่ทั้งหมด เพียงเล็กน้อย**
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## ขยายรายละเอียดจาก boxplot ข้างบน

loans.groupby('loan_status')['int_rate'].describe()
# Out:
#                 count       mean       std   min    25%    50%    75%    max
# loan_status
# Charged Off  152999.0  15.864707  5.451607  5.31  11.49  14.99  18.99  30.99
# Fully Paid   583755.0  12.515300  4.843605  5.31   8.59  11.49  14.99  30.99

# %%
lowCorrCols_list.append('int_rate')
lowCorrCols_list
# Out:
# ['int_rate']

# %% [markdown]
# ### **2.2.3 Installment**

# %%
loans['installment'].describe()
# Out:
# count    736754.000000
# mean        446.576084
# std         282.946410
# min          30.120000
# 25%         238.110000
# 50%         370.480000
# 75%         602.300000
# max        1715.420000
# Name: installment, dtype: float64

# %%
plot_var(loans,'installment', 'Installment', continuous=True)

### จากผลการวิเคราะห์ด้วย BoxPlot พบว่า Installment ของ Fully Paid กับ Charged Off มี mean ของ Installment ที่ต่างกัน
### ดังนี้แล้วจึงแปรผลได้ว่า การผ่อนชำระที่แตกต่างกัน มีความสัมพันธ์เกี่ยวข้องกับ การชำระหนี้คืนทั้งหมด หรือไม่ทั้งหมด อยู่พอสมควร
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## ขยายรายละเอียดจาก boxplot ข้างบน

loans.groupby('loan_status')['installment'].describe()
# Out:
#                 count        mean         std    min     25%     50%     75%  \
# loan_status
# Charged Off  152999.0  486.490664  287.133256  30.12  273.39  413.00  651.25
# Fully Paid   583755.0  436.114690  280.902528  30.12  229.14  360.08  587.17
#
#                  max
# loan_status
# Charged Off  1676.23
# Fully Paid   1715.42

# %% [markdown]
# ### **2.2.4 Employment Length**

# %%
## แสดงทุกค่าใน emp_length โดยแสดงค่า null ด้วย และมีการจัดเรียงตาม index ก่อนแสดง

loans['emp_length'].value_counts(dropna=False).sort_index()
# Out:
# 1 year        49886
# 10+ years    247496
# 2 years       68493
# 3 years       60901
# 4 years       44489
# 5 years       45876
# 6 years       32116
# 7 years       24839
# 8 years       28125
# 9 years       26475
# < 1 year      55912
# NaN           52146
# Name: emp_length, dtype: int64

# %%
## แสดงค่าใน emp_length

loans['emp_length'].value_counts(dropna=False).sort_index()
# Out:
# 1 year        49886
# 10+ years    247496
# 2 years       68493
# 3 years       60901
# 4 years       44489
# 5 years       45876
# 6 years       32116
# 7 years       24839
# 8 years       28125
# 9 years       26475
# < 1 year      55912
# NaN           52146
# Name: emp_length, dtype: int64

# %%
## เปลียน Null ใน emp_length เป็น 'N/A'

loans['emp_length'] = loans[['emp_length']].apply( lambda x:x.replace(to_replace=np.nan, value='N/A'))

# %%
plot_var(loans,'emp_length', 'Employment Length', continuous=False)

### จากผลการวิเคราะห์ด้วย Bar Chart พบว่า Charged off ดูไม่แตกต่างกันในระยะเวลาเวลาการจ้างงาน (emp_length) โดยส่วนใหญ่
### แต่ ค่า Null ในระยะเวลาการจ้างงาน ('N/A') มี Charged off สูงแตกต่างจากระยะเวลาการจ้างงานอื่นๆ 
### ดังนี้จึงแปลผลได้ว่า การไม่ระบุระยะเวลาการจ้าง มีสัมพันธ์กับการไม่จ่ายหนี้คืน **
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
highCorrCols_list.append('emp_length')
highCorrCols_list
# Out:
# ['emp_length']

# %% [markdown]
# ### **2.2.5 Annual Income**

# %%
loans['annual_inc'].describe()
# Out:
# count    7.367540e+05
# mean     7.949849e+04
# std      7.809475e+04
# min      0.000000e+00
# 25%      4.800000e+04
# 50%      6.700000e+04
# 75%      9.500000e+04
# max      9.573072e+06
# Name: annual_inc, dtype: float64

# %%
plot_var(loans,'annual_inc', 'Annual Income', continuous=True)

### จากผลการวิเคราะห์ด้วยเทคนิค boxplot ยังไม่สามารถอ่านผลที่ชัดเจนในด้านความพันธ์ 
### แต่จาก upper-fencing ของ boxplot พบว่า มี data points ของ annual_inc ที่สูงกว่า upper-fencing เป็นจำนวนมาก
### เช่นนี้แปลผลได้ว่า annual_inc มี outlier จำนวนมากแฝงอยู่ในข้อมูล **
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
max_annual_inc = loans['annual_inc'].max()

# %%
min_annual_inc = loans['annual_inc'].min()

# %%
loans['annual_inc'] = loans['annual_inc'].apply(lambda x: ((x-min_annual_inc)/(max_annual_inc-min_annual_inc)))

# %%
plot_var(loans,'annual_inc', 'Normalized Annual Income', continuous=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
loans['annual_inc'].describe()
# Out:
# count    736754.000000
# mean          0.008304
# std           0.008158
# min           0.000000
# 25%           0.005014
# 50%           0.006999
# 75%           0.009924
# max           1.000000
# Name: annual_inc, dtype: float64

# %%
#outlierCols_list.append('annual_inc')
outlierCols_list
# Out:
# []

# %% [markdown]
# ### **2.2.6 Debt to Income**

# %%
plot_var(loans,'dti', 'Debt to Income', continuous=True)

### จากผลการวิเคราะห์ด้วยเทคนิค boxplot ยังไม่สามารถอ่านผลที่ชัดเจนในด้านความพันธ์ 
### แต่จาก upper-fencing ของ boxplot พบว่า มี data points ของ dti ที่สูงกว่า upper-fencing เป็นจำนวนมาก
### เช่นนี้แปลผลได้ว่า dti มี outlier จำนวนมากแฝงอยู่ในข้อมูล **
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
outlierCols_list.append('dti')
outlierCols_list
# Out:
# ['dti']

# %% [markdown]
# ### **2.2.7 delinq.2yrs: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.**

# %%
numCol_list
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
#        'annual_inc', 'dti', 'delinq_2yrs', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'total_pymnt', 'total_pymnt_inv'],
#       dtype='object')

# %%
catCol_list
# Out:
# Index(['term', 'int_rate', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'revol_util', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'application_type', 'hardship_flag',
#        'debt_settlement_flag'],
#       dtype='object')

# %%
plot_var(loans,'delinq_2yrs', 'delinq_2yrs', continuous=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
loans['delinq_2yrs'].value_counts()
# Out:
# 0.0     591859
# 1.0      96038
# 2.0      27914
# 3.0      10275
# 4.0       4729
# 5.0       2370
# 6.0       1396
# 7.0        777
# 8.0        437
# 9.0        293
# 10.0       236
# 11.0       140
# 12.0        95
# 13.0        49
# 14.0        44
# 15.0        31
# 16.0        20
# 18.0        13
# 19.0        11
# 20.0        10
# 17.0         9
# 21.0         6
# 22.0         1
# 29.0         1
# Name: delinq_2yrs, dtype: int64

# %%
outlierCols_list.append('delinq_2yrs')
outlierCols_list
# Out:
# ['dti', 'delinq_2yrs']

# %% [markdown]
# ### **2.2.8 revol.util: The borrower’s revolving line utilization rate (the amount of the credit line used relative to total credit available).**

# %%
loans['revol_util'] = loans[['revol_util']].apply(lambda x: x.replace(to_replace=np.nan,value='N/A'))

# %%
#plot_var(loans,'revol_util', 'revol_util', continuous=False)

# %%
#categorical = list(loans.select_dtypes('object').columns)

#numerical = list(loans.select_dtypes('number').columns)

# %%
#categorical

# %%
#numerical

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 736754 entries, 0 to 1432462
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             736754 non-null  float64
#  1   funded_amnt           736754 non-null  float64
#  2   funded_amnt_inv       736754 non-null  float64
#  3   term                  736754 non-null  object
#  4   int_rate              736754 non-null  float64
#  5   installment           736754 non-null  float64
#  6   grade                 736754 non-null  object
#  7   sub_grade             736754 non-null  object
#  8   emp_title             681958 non-null  object
#  9   emp_length            736754 non-null  object
#  10  home_ownership        736754 non-null  object
#  11  annual_inc            736754 non-null  float64
#  12  verification_status   736754 non-null  object
#  13  issue_d               736754 non-null  object
#  14  loan_status           736754 non-null  object
#  15  pymnt_plan            736754 non-null  object
#  16  purpose               736754 non-null  object
#  17  title                 716182 non-null  object
#  18  zip_code              736750 non-null  object
#  19  addr_state            736754 non-null  object
#  20  dti                   736282 non-null  float64
#  21  delinq_2yrs           736754 non-null  float64
#  22  earliest_cr_line      736754 non-null  object
#  23  open_acc              736754 non-null  float64
#  24  pub_rec               736754 non-null  float64
#  25  revol_bal             736754 non-null  float64
#  26  revol_util            736754 non-null  object
#  27  total_acc             736754 non-null  float64
#  28  initial_list_status   736754 non-null  object
#  29  total_pymnt           736754 non-null  float64
#  30  total_pymnt_inv       736754 non-null  float64
#  31  last_pymnt_d          734937 non-null  object
#  32  last_credit_pull_d    736738 non-null  object
#  33  application_type      736754 non-null  object
#  34  hardship_flag         736754 non-null  object
#  35  debt_settlement_flag  736754 non-null  object
# dtypes: float64(14), object(22)
# memory usage: 224.1+ MB

# %% [markdown]
# # **3. Feature Engineering and Feature Selection**

# %% [markdown]
# ## **3.1 สร้าง Dummy Variables/Columns**

# %%
loans['charged_off'] = (loans['loan_status'] == 'Charged Off').apply(np.uint8)
loans.drop('loan_status', axis=1, inplace=True)

# %%
loans['charged_off'].value_counts()
# Out:
# 0    583755
# 1    152999
# Name: charged_off, dtype: int64

# %%
## สร้าง dummy vars./cols. 

tobeDummy_columns = ["grade","emp_length","home_ownership", "verification_status", "purpose", "term"]
dummy_df = pd.get_dummies(loans[tobeDummy_columns])
loans = pd.concat([loans, dummy_df], axis=1)
loans = loans.drop(tobeDummy_columns, axis=1)

# %%
## แสดงรายชื่อ cols หลังจากเพิ่ม dummy vars./cols.

pd.DataFrame(loans.columns.sort_values())
# Out:
#                                       0
# 0                            addr_state
# 1                            annual_inc
# 2                      application_type
# 3                           charged_off
# 4                  debt_settlement_flag
# 5                           delinq_2yrs
# 6                                   dti
# 7                      earliest_cr_line
# 8                     emp_length_1 year
# 9                  emp_length_10+ years
# 10                   emp_length_2 years
# 11                   emp_length_3 years
# 12                   emp_length_4 years
# 13                   emp_length_5 years
# 14                   emp_length_6 years
# 15                   emp_length_7 years
# 16                   emp_length_8 years
# 17                   emp_length_9 years
# 18                  emp_length_< 1 year
# 19                       emp_length_N/A
# 20                            emp_title
# 21                          funded_amnt
# 22                      funded_amnt_inv
# 23                              grade_A
# 24                              grade_B
# 25                              grade_C
# 26                              grade_D
# 27                              grade_E
# 28                              grade_F
# 29                              grade_G
# 30                        hardship_flag
# 31                   home_ownership_ANY
# 32              home_ownership_MORTGAGE
# 33                  home_ownership_NONE
# 34                   home_ownership_OWN
# 35                  home_ownership_RENT
# 36                  initial_list_status
# 37                          installment
# 38                             int_rate
# 39                              issue_d
# 40                   last_credit_pull_d
# 41                         last_pymnt_d
# 42                            loan_amnt
# 43                             open_acc
# 44                              pub_rec
# 45                          purpose_car
# 46                  purpose_credit_card
# 47           purpose_debt_consolidation
# 48             purpose_home_improvement
# 49                        purpose_house
# 50               purpose_major_purchase
# 51                      purpose_medical
# 52                       purpose_moving
# 53                        purpose_other
# 54             purpose_renewable_energy
# 55               purpose_small_business
# 56                     purpose_vacation
# 57                      purpose_wedding
# 58                           pymnt_plan
# 59                            revol_bal
# 60                           revol_util
# 61                            sub_grade
# 62                      term_ 36 months
# 63                      term_ 60 months
# 64                                title
# 65                            total_acc
# 66                          total_pymnt
# 67                      total_pymnt_inv
# 68     verification_status_Not Verified
# 69  verification_status_Source Verified
# 70         verification_status_Verified
# 71                             zip_code

# %%
print('columns หลังจากเพิ่ม dummy vars./cols. มีจำนวน: %2d'%(len(loans.axes[1].values)))
# Out:
# columns หลังจากเพิ่ม dummy vars./cols. มีจำนวน: 72

# %% [markdown]
# ------------------------------สิ่งที่ได้รับตอนนี้ คือ ชื่อ Dummy Variables (ผ่านการทำ Encoding)------------------------------

# %% [markdown]
# ### **3.2 Feature Selection**

# %%
print(nullCols_list)

print(outlierCols_list)

print(highScaleCols_list)

print(highDispersionCols_list)

print(highCorrCols_list)

print(lowCorrCols_list)

print(numCol_list)

print(catCol_list)
# Out:
# ['emp_title', 'emp_length', 'title', 'zip_code', 'dti', 'revol_util', 'last_pymnt_d', 'last_credit_pull_d']
# ['dti', 'delinq_2yrs']
# []
# ['delinq_2yrs', 'pub_rec', 'revol_bal']
# ['emp_length']
# ['int_rate']
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
#        'annual_inc', 'dti', 'delinq_2yrs', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'total_pymnt', 'total_pymnt_inv'],
#       dtype='object')
# Index(['term', 'int_rate', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'revol_util', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'application_type', 'hardship_flag',
#        'debt_settlement_flag'],
#       dtype='object')

# %%
# *** finally drop columns

loans = loans.drop('revol_util',axis=1)\
.drop(['dti',
 'open_acc',
 'revol_bal'],axis=1)\
 .drop([x for x in loans.axes[1].values.tolist() if 'purpose_' in x],axis=1)\
 .drop([x for x in loans.axes[1].values.tolist() if '_pymnt' in x],axis=1)\
 .drop([x for x in loans.axes[1].values.tolist() if 'num_' in x],axis=1)\
 .drop([x for x in loans.axes[1].values.tolist() if 'funded_' in x],axis=1)\
 .drop(temp_IgnoredCols_list,errors='ignore',axis=1)\
 .drop(outlierCols_list,errors='ignore',axis=1)\
 .drop([x for x in loans.axes[1].values.tolist() if 'term_' in x],errors='ignore',axis=1)

# %% [markdown]
# ------------------------------สิ่งที่ได้รับตอนนี้ คือ ชื่อ Feature ที่คาดว่ามีความสัมพันธ์กับ Label------------------------------

# %% [markdown]
# ## **3.2 สร้าง Training Set และ Testing Set**

# %%
loans['issue_d'].sample(5)
# Out:
# 68167      Mar-2016
# 1158582    Jul-2018
# 586104     Feb-2017
# 200776     May-2016
# 56701      Mar-2016
# Name: issue_d, dtype: object

# %%
loans['issue_d'].isnull().any()
# Out:
# False

# %%
## เปลี่ยน data type ของ issue_d เป็น datetime
loans['issue_d'] = pd.to_datetime(loans['issue_d'])

# %%
loans['issue_d'].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                  736754
# unique                     30
# top       2017-03-01 00:00:00
# freq                    86864
# first     2016-01-01 00:00:00
# last      2019-03-01 00:00:00
# Name: issue_d, dtype: object

# %%
plt.figure(figsize=(6,3), dpi=90)
loans['issue_d'].dt.year.value_counts().sort_index().plot.bar(color='darkblue')
plt.xlabel('Year')
plt.ylabel('Number of Loans Funded')
plt.title('Loans Funded per Year')
# Out:
# Text(0.5, 1.0, 'Loans Funded per Year')

# %%
# สร้าง training set และ testing set ซึ่งเป็นแบบ Hand-out testing set
# โดยข้อมูลที่เก่ากว่า issue_d ที่ quantile 0.9 ถูกนำมาสุ่มเลือกเพื่อเป็น training set
# ส่วนข้อมูลที่ใหม่กว่าฯ ถูกนำมาสุ่มเลือกเพื่อเป็น testing set
loans_train = loans.loc[loans['issue_d'] < loans['issue_d'].quantile(0.9)].sample(300000).dropna() 
loans_test = loans.loc[loans['issue_d'] >= loans['issue_d'].quantile(0.9)].sample(10000).dropna()

# %%
# นับจำนวน Fully Paid หรือ Charged Off 
# ผลการนับพบว่า มีจำนวน Fully Paid กับ Charged Off ต่างกันค่อนข้างมาก
# ความต่างกันลักษณะนี้ เรียกว่า "Imbalance Classes"

charged_off_pd = loans_train[loans_train['charged_off'] == 1]
fully_paid_pd = loans_train[loans_train['charged_off'] == 0]
print(charged_off_pd.shape)
print(fully_paid_pd.shape)
# Out:
# (55487, 47)
# (215684, 47)

# %%
# แก้ไข Imbalance Classes ด้วยการ upsampling เฉพาะ Charge Off

from sklearn.utils import resample
fullyPaid_downsample = resample(fully_paid_pd,
             replace=True,
             n_samples=len(charged_off_pd),
             random_state=42)

print(fullyPaid_downsample.shape)
# Out:
# (55487, 47)

# %%
#Merge rows ที่เป็น Fully Paid และ Charge Off ที่ผ่านการทำ upsampling แล้ว เข้าด้วยกัน

loans_train = pd.concat([fullyPaid_downsample, charged_off_pd])
print(loans_train[loans_train['charged_off']==1].shape)
print(loans_train[loans_train['charged_off']==0].shape)
# Out:
# (55487, 47)
# (55487, 47)

# %%
print('Number of loans in the training and testing set:   ', loans_train.shape[0] + loans_test.shape[0])
print('Number of loans in the full dataset:', loans.shape[0])
# Out:
# Number of loans in the training and testing set:    119848
# Number of loans in the full dataset: 736754

# %%
loans_test.shape[0]
# Out:
# 8874

# %%
loans_test.shape[0] / loans.shape[0]
# Out:
# 0.012044725919370645

# %%
## แสดงให้เห็นว่า ข้อมูลที่เอามา Train ไม่เคยอยู่ใน Test

loans_train['issue_d'].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   This is separate from the ipykernel package so we can avoid doing imports until
# count                  110974
# unique                     19
# top       2017-03-01 00:00:00
# freq                    15468
# first     2016-01-01 00:00:00
# last      2018-04-01 00:00:00
# Name: issue_d, dtype: object

# %%
## แสดงให้เห็นว่า ข้อมูลที่เอามา Test ไม่เคยอยู่ใน Train

loans_test['issue_d'].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   This is separate from the ipykernel package so we can avoid doing imports until
# count                    8874
# unique                     11
# top       2018-05-01 00:00:00
# freq                     1441
# first     2018-05-01 00:00:00
# last      2019-03-01 00:00:00
# Name: issue_d, dtype: object

# %%
loans_train = loans_train.drop('issue_d',axis=1)
loans_test = loans_test.drop('issue_d',axis=1)

# %%
y_train = loans_train['charged_off']
y_test = loans_test['charged_off']

# %%
X_train = loans_train.drop('charged_off', axis=1)
X_test = loans_test.drop('charged_off', axis=1)

# %% [markdown]
# ------------------------------สิ่งที่ได้รับตอนนี้ Training set และ Testing set เก็บอยู่ในตัวแปรทั้งหมด 4 ตัว------------------------------

# %% [markdown]
# ## **3.3 Feature Selection on Training Set using Bar Chart**

# %%
def feature_plot_var(arg_df, col_name, full_name, continuous):
    """
    Visualize a variable with and without faceting on the loan status.
    - col_name is the variable name in the dataframe
    - full_name is the full variable name
    - continuous is True if the variable is continuous, False otherwise
    """
    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
    
    # Plot without loan status
    if continuous:
        sns.distplot(arg_df.loc[arg_df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(arg_df[col_name], order=sorted(arg_df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(full_name)
    ax1.set_ylabel('Count')
    ax1.set_title(full_name)

    # Plot with loan status
    if continuous:
        sns.boxplot(x=col_name, y='charged_off', data=arg_df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
    else:
        charge_off_rates = arg_df.groupby(col_name)['charged_off'].value_counts(normalize=True).loc[:,1]
        sns.barplot(x=charge_off_rates.index, y=charge_off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of arg_df Charged-off')
        ax2.set_title('Charge-off Rate by ' + full_name)
    ax2.set_xlabel(full_name)
    
    plt.tight_layout()

# %%
loans.select_dtypes('number').columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'pub_rec',
#        'total_acc', 'charged_off', 'grade_A', 'grade_B', 'grade_C', 'grade_D',
#        'grade_E', 'grade_F', 'grade_G', 'emp_length_1 year',
#        'emp_length_10+ years', 'emp_length_2 years', 'emp_length_3 years',
#        'emp_length_4 years', 'emp_length_5 years', 'emp_length_6 years',
#        'emp_length_7 years', 'emp_length_8 years', 'emp_length_9 years',
#        'emp_length_< 1 year', 'emp_length_N/A', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE', 'home_ownership_OWN',
#        'home_ownership_RENT', 'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified'],
#       dtype='object')

# %%
corrTestCols_list = ['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'pub_rec',
       'total_acc','charged_off']

# %%
# Plot
#plt.figure(figsize=(10,8), dpi= 80)
#sns.pairplot(loans[corrTestCols_list], kind="scatter", hue="charged_off", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
#plt.show()

# %%
for testCol in [x for x in loans_train.axes[1].values.tolist() if 'grade' in x]:
  feature_plot_var(loans_train,testCol, testCol, continuous=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
for testCol in [x for x in loans_train.axes[1].values.tolist() if 'delinq_2yrs' in x]:
  feature_plot_var(loans_train,testCol, testCol, continuous=False)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'inq_last_6mths' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=False)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'open_acc' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=True)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'revol_bal' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=True)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'total_acc' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=True)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'dti' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=True)

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'pub_rec' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=False)

# %%
for testCol in [x for x in loans_train.axes[1].values.tolist() if 'term_' in x]:
  feature_plot_var(loans_train,testCol, testCol, continuous=False)

# %%
for testCol in [x for x in loans_train.axes[1].values.tolist() if 'home_' in x]:
  feature_plot_var(loans_train,testCol, testCol, continuous=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#for testCol in [x for x in loans_train.axes[1].values.tolist() if 'purpose_' in x]:
  #feature_plot_var(loans_train,testCol, testCol, continuous=False)

# %%
for testCol in [x for x in loans_train.axes[1].values.tolist() if 'verification_' in x]:
  feature_plot_var(loans_train,testCol, testCol, continuous=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
loans_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110974 entries, 523748 to 244093
# Data columns (total 46 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            110974 non-null  float64
#  1   int_rate                             110974 non-null  float64
#  2   installment                          110974 non-null  float64
#  3   sub_grade                            110974 non-null  object
#  4   emp_title                            110974 non-null  object
#  5   annual_inc                           110974 non-null  float64
#  6   pymnt_plan                           110974 non-null  object
#  7   title                                110974 non-null  object
#  8   zip_code                             110974 non-null  object
#  9   addr_state                           110974 non-null  object
#  10  earliest_cr_line                     110974 non-null  object
#  11  pub_rec                              110974 non-null  float64
#  12  total_acc                            110974 non-null  float64
#  13  initial_list_status                  110974 non-null  object
#  14  last_credit_pull_d                   110974 non-null  object
#  15  application_type                     110974 non-null  object
#  16  hardship_flag                        110974 non-null  object
#  17  debt_settlement_flag                 110974 non-null  object
#  18  charged_off                          110974 non-null  int8
#  19  grade_A                              110974 non-null  uint8
#  20  grade_B                              110974 non-null  uint8
#  21  grade_C                              110974 non-null  uint8
#  22  grade_D                              110974 non-null  uint8
#  23  grade_E                              110974 non-null  uint8
#  24  grade_F                              110974 non-null  uint8
#  25  grade_G                              110974 non-null  uint8
#  26  emp_length_1 year                    110974 non-null  uint8
#  27  emp_length_10+ years                 110974 non-null  uint8
#  28  emp_length_2 years                   110974 non-null  uint8
#  29  emp_length_3 years                   110974 non-null  uint8
#  30  emp_length_4 years                   110974 non-null  uint8
#  31  emp_length_5 years                   110974 non-null  uint8
#  32  emp_length_6 years                   110974 non-null  uint8
#  33  emp_length_7 years                   110974 non-null  uint8
#  34  emp_length_8 years                   110974 non-null  uint8
#  35  emp_length_9 years                   110974 non-null  uint8
#  36  emp_length_< 1 year                  110974 non-null  uint8
#  37  emp_length_N/A                       110974 non-null  uint8
#  38  home_ownership_ANY                   110974 non-null  uint8
#  39  home_ownership_MORTGAGE              110974 non-null  uint8
#  40  home_ownership_NONE                  110974 non-null  uint8
#  41  home_ownership_OWN                   110974 non-null  uint8
#  42  home_ownership_RENT                  110974 non-null  uint8
#  43  verification_status_Not Verified     110974 non-null  uint8
#  44  verification_status_Source Verified  110974 non-null  uint8
#  45  verification_status_Verified         110974 non-null  uint8
# dtypes: float64(6), int8(1), object(12), uint8(27)
# memory usage: 23.1+ MB

# %%
## ทดสอบเกณฑ์การประเมิน

import pandas as pd
import numpy as np
predictions = pd.Series(np.ones(loans.shape[0])) ## สร้าง prediction แบบ series ขึ้นมารับค่า 1 ตามจำนวน row ของ loans โดยสมมติว่า prediction เป็น charged off ทั้งหมด
# False positives.
fp_filter = (predictions == 1) & (loans["charged_off"] == 0)
fp = len(predictions[fp_filter])

# True positives.
tp_filter = (predictions == 1) & (loans["charged_off"] == 1)
tp = len(predictions[tp_filter])

# False negatives.
fn_filter = (predictions == 0) & (loans["charged_off"] == 1)
fn = len(predictions[fn_filter])

# True negatives
tn_filter = (predictions == 0) & (loans["charged_off"] == 0)
tn = len(predictions[tn_filter])

# %%
## ผลการทดสอบเครื่องมือเฉพาะด้าน Positive Side - เฉพาะรายที่ Charged Off
tpr = tp / (tp + fn)
fpr = fp / (fp + tn)

print(tpr)
print(fpr)
# Out:
# 1.0
# 1.0

# %%
# สรุป ABT 
print ('จำนวน Training set เฉพาะ Features: %1d rows'%(len(X_train)))

print ('จำนวน Training set เฉพาะ Label: %1d rows'%(len(y_train))) 

print ('จำนวน Testing set เฉพาะ Features: %1d rows'%(len(X_test)))

print ('จำนวน Testing set เฉพาะ Label: %1d rows'%(len(y_test)))
# Out:
# จำนวน Training set เฉพาะ Features: 110974 rows
# จำนวน Training set เฉพาะ Label: 110974 rows
# จำนวน Testing set เฉพาะ Features: 8874 rows
# จำนวน Testing set เฉพาะ Label: 8874 rows

# %%
#del loans_train, loans_test

# %%
#del loans

# %% [markdown]
# # **4. Modeling and Evaluation**

# %%
# สรุป Feature ใน Training set
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110974 entries, 523748 to 244093
# Data columns (total 45 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            110974 non-null  float64
#  1   int_rate                             110974 non-null  float64
#  2   installment                          110974 non-null  float64
#  3   sub_grade                            110974 non-null  object
#  4   emp_title                            110974 non-null  object
#  5   annual_inc                           110974 non-null  float64
#  6   pymnt_plan                           110974 non-null  object
#  7   title                                110974 non-null  object
#  8   zip_code                             110974 non-null  object
#  9   addr_state                           110974 non-null  object
#  10  earliest_cr_line                     110974 non-null  object
#  11  pub_rec                              110974 non-null  float64
#  12  total_acc                            110974 non-null  float64
#  13  initial_list_status                  110974 non-null  object
#  14  last_credit_pull_d                   110974 non-null  object
#  15  application_type                     110974 non-null  object
#  16  hardship_flag                        110974 non-null  object
#  17  debt_settlement_flag                 110974 non-null  object
#  18  grade_A                              110974 non-null  uint8
#  19  grade_B                              110974 non-null  uint8
#  20  grade_C                              110974 non-null  uint8
#  21  grade_D                              110974 non-null  uint8
#  22  grade_E                              110974 non-null  uint8
#  23  grade_F                              110974 non-null  uint8
#  24  grade_G                              110974 non-null  uint8
#  25  emp_length_1 year                    110974 non-null  uint8
#  26  emp_length_10+ years                 110974 non-null  uint8
#  27  emp_length_2 years                   110974 non-null  uint8
#  28  emp_length_3 years                   110974 non-null  uint8
#  29  emp_length_4 years                   110974 non-null  uint8
#  30  emp_length_5 years                   110974 non-null  uint8
#  31  emp_length_6 years                   110974 non-null  uint8
#  32  emp_length_7 years                   110974 non-null  uint8
#  33  emp_length_8 years                   110974 non-null  uint8
#  34  emp_length_9 years                   110974 non-null  uint8
#  35  emp_length_< 1 year                  110974 non-null  uint8
#  36  emp_length_N/A                       110974 non-null  uint8
#  37  home_ownership_ANY                   110974 non-null  uint8
#  38  home_ownership_MORTGAGE              110974 non-null  uint8
#  39  home_ownership_NONE                  110974 non-null  uint8
#  40  home_ownership_OWN                   110974 non-null  uint8
#  41  home_ownership_RENT                  110974 non-null  uint8
#  42  verification_status_Not Verified     110974 non-null  uint8
#  43  verification_status_Source Verified  110974 non-null  uint8
#  44  verification_status_Verified         110974 non-null  uint8
# dtypes: float64(6), object(12), uint8(27)
# memory usage: 23.0+ MB

# %%
# สรุป Label เฉพาะ Charge Off ใน Training set

len(y_train[y_train==1])
# Out:
# 55487

# %%
# สรุป Label เฉพาะ Fully Paid ใน Training set

len(y_train[y_train==0])
# Out:
# 55487

# %%
#X_train.columns.tolist()

# %%
import pandas as pd
from seaborn import load_dataset
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# รวบรวมชื่อ Column ที่เป็น String เก็บไว้ในตัวแปรชื่อ categorical
categorical = list(X_train.select_dtypes('object').columns)
print(f"Categorical columns are: {categorical}")

# รวบรวมชื่อ Column ที่เป็น numerical เก็บไว้ในตัวแปรชื่อ numerical
numerical = list(X_train.select_dtypes('number').columns)
print(f"Numerical columns are: {numerical}")
# Out:
# Categorical columns are: ['sub_grade', 'emp_title', 'pymnt_plan', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'last_credit_pull_d', 'application_type', 'hardship_flag', 'debt_settlement_flag']
# Numerical columns are: ['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'pub_rec', 'total_acc', 'grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F', 'grade_G', 'emp_length_1 year', 'emp_length_10+ years', 'emp_length_2 years', 'emp_length_3 years', 'emp_length_4 years', 'emp_length_5 years', 'emp_length_6 years', 'emp_length_7 years', 'emp_length_8 years', 'emp_length_9 years', 'emp_length_< 1 year', 'emp_length_N/A', 'home_ownership_ANY', 'home_ownership_MORTGAGE', 'home_ownership_NONE', 'home_ownership_OWN', 'home_ownership_RENT', 'verification_status_Not Verified', 'verification_status_Source Verified', 'verification_status_Verified']

# %% [markdown]
# ## **4.1 Logistic Regression**

# %%
# กำหนด ML Algorithm
lr = LogisticRegression()

# เลือกเฉพาะ Numerical variables มาสร้างโมเดล
# train_cols = X_train[numerical].columns.tolist()

# เลือกเฉพาะ Numerical variables มาเป็น Feature
# แล้วส่ง Feature เก็บไว้ในตัวแปรชื่อ features
features = X_train[numerical]

# ส่ง Label เก็บไว้ในตัวแปรชื่อ target
target = y_train

# สร้าง ML Model
lr.fit(features, target)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix

# การนำ model lr มา make prediction โดยค่าที่ predict ถูกเก็บไว้ใน y_pred
y_pred = lr.predict(X_test[numerical]).flatten()

# นำค่าที่ predict (y_pred) มาเปรียบเทียบกับค่าจริงที่อยู่ใน y_test
cm = confusion_matrix(y_test,y_pred)

# สรุปผลการเปรียบเทียบด้วย Confusion Matrix
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted     0     1   All
# Actual
# 0          3038  4351  7389
# 1           361  1124  1485
# All        3399  5475  8874

# %%
from sklearn.metrics import confusion_matrix

# นำผลการเปรียบเทียบมาคำนวณ เพื่อประเมินตามเกณฑ์
#cm = confusion_matrix(y_test, y_pred)
#print("Confusion Matrix (predict/actual):\n", pd.DataFrame(cm))
lr.score(X_test[numerical], y_test)


#เกณฑ์ recall
recall = np.diag(cm) / np.sum(cm, axis=1)
print("\nRecall:\n", pd.Series(recall))

#เกณฑ์ precision
precision = np.diag(cm) / np.sum(cm, axis=0)
print("\nPrecision:\n", pd.Series(precision))

#เกณฑ์ f1
from sklearn.metrics import f1_score
weighted_f1 = f1_score(y_test, y_pred, average="weighted")
print("\nF1 score:\n", weighted_f1)
# Out:
# Recall:
#  0    0.411152
# 1    0.756902
# dtype: float64
#
# Precision:
#  0    0.893792
# 1    0.205297
# dtype: float64
#
# F1 score:
#  0.523017649390315

# %%
# ลบโมเดล lr

del lr

# %% [markdown]
# ## **4.2 Random Forest Classifier**

# %%
RFC = RandomForestClassifier()
#cols = loans.columns
train_cols = X_train[numerical].columns.tolist()
features = X_train[numerical]
target = y_train
RFC.fit(features, target)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix

y_pred = RFC.predict(X_test[numerical]).flatten()
cm = confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted     0     1   All
# Actual
# 0          4558  2831  7389
# 1           533   952  1485
# All        5091  3783  8874

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix (predict/actual):\n", pd.DataFrame(cm))


RFC.score(X_test[numerical], y_test)

recall = np.diag(cm) / np.sum(cm, axis=1)
print("\nRecall:\n", pd.Series(recall))

precision = np.diag(cm) / np.sum(cm, axis=0)
print("\nPrecision:\n", pd.Series(precision))


from sklearn.metrics import f1_score
weighted_f1 = f1_score(y_test, y_pred, average="weighted")
print("\nF1 score:\n", weighted_f1)
# Out:
# Confusion Matrix (predict/actual):
#        0     1
# 0  4558  2831
# 1   533   952
#
# Recall:
#  0    0.616863
# 1    0.641077
# dtype: float64
#
# Precision:
#  0    0.895305
# 1    0.251652
# dtype: float64
#
# F1 score:
#  0.6686956721535645

# %%
X_train[numerical].columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'pub_rec',
#        'total_acc', 'grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E',
#        'grade_F', 'grade_G', 'emp_length_1 year', 'emp_length_10+ years',
#        'emp_length_2 years', 'emp_length_3 years', 'emp_length_4 years',
#        'emp_length_5 years', 'emp_length_6 years', 'emp_length_7 years',
#        'emp_length_8 years', 'emp_length_9 years', 'emp_length_< 1 year',
#        'emp_length_N/A', 'home_ownership_ANY', 'home_ownership_MORTGAGE',
#        'home_ownership_NONE', 'home_ownership_OWN', 'home_ownership_RENT',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified'],
#       dtype='object')

# %%
del RFC

# %% [markdown]
# ## **4.3 Decision Tree Classifier**

# %%
DT = DecisionTreeClassifier()
#cols = loans.columns
train_cols = X_train[numerical].columns.tolist()
features = X_train[numerical]
target = y_train
DT.fit(features, target)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import confusion_matrix

y_pred = DT.predict(X_test[numerical]).flatten()
cm = confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted     0     1   All
# Actual
# 0          4005  3384  7389
# 1           674   811  1485
# All        4679  4195  8874

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix (predict/actual):\n", pd.DataFrame(cm))


DT.score(X_test[numerical], y_test)

recall = np.diag(cm) / np.sum(cm, axis=1)
print("\nRecall:\n", pd.Series(recall))

precision = np.diag(cm) / np.sum(cm, axis=0)
print("\nPrecision:\n", pd.Series(precision))


from sklearn.metrics import f1_score
weighted_f1 = f1_score(y_test, y_pred, average="weighted")
print("\nF1 score:\n", weighted_f1)
# Out:
# Confusion Matrix (predict/actual):
#        0     1
# 0  4005  3384
# 1   674   811
#
# Recall:
#  0    0.542022
# 1    0.546128
# dtype: float64
#
# Precision:
#  0    0.855952
# 1    0.193325
# dtype: float64
#
# F1 score:
#  0.6004538778299329

# %%
del DT

# %%
X_train[numerical].columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'pub_rec',
#        'total_acc', 'grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E',
#        'grade_F', 'grade_G', 'emp_length_1 year', 'emp_length_10+ years',
#        'emp_length_2 years', 'emp_length_3 years', 'emp_length_4 years',
#        'emp_length_5 years', 'emp_length_6 years', 'emp_length_7 years',
#        'emp_length_8 years', 'emp_length_9 years', 'emp_length_< 1 year',
#        'emp_length_N/A', 'home_ownership_ANY', 'home_ownership_MORTGAGE',
#        'home_ownership_NONE', 'home_ownership_OWN', 'home_ownership_RENT',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified'],
#       dtype='object')

# %%
nullCols_list
# Out:
# ['emp_title',
#  'emp_length',
#  'title',
#  'zip_code',
#  'dti',
#  'revol_util',
#  'last_pymnt_d',
#  'last_credit_pull_d']

# %%
outlierCols_list
# Out:
# ['dti', 'delinq_2yrs']

# %%
#typeMismatchCols_list

# %%
highScaleCols_list
# Out:
# []

# %%
highCorrCols_list
# Out:
# ['emp_length']

# %%
lowCorrCols_list
# Out:
# ['int_rate']

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.dummy import DummyClassifier
import warnings
warnings.simplefilter("ignore")

# %%
classifiers = {
    "Dummy"        : DummyClassifier(strategy='uniform', random_state=2),
    "KNN(3)"       : KNeighborsClassifier(3), 
    "RBF SVM"      : SVC(gamma=2, C=1), 
    "Decision Tree": DecisionTreeClassifier(max_depth=7), 
    "Random Forest": RandomForestClassifier(max_depth=7, n_estimators=10, max_features=4), 
    "Neural Net"   : MLPClassifier(alpha=1), 
    "AdaBoost"     : AdaBoostClassifier(),
    "Naive Bayes"  : GaussianNB(), 
    "QDA"          : QuadraticDiscriminantAnalysis(),
    "Linear SVC"   : LinearSVC(),
    "Linear SVM"   : SVC(kernel="linear"), 
    "Gaussian Proc": GaussianProcessClassifier(1.0 * RBF(1.0)),
}

# %%
numerical
# Out:
# ['loan_amnt',
#  'int_rate',
#  'installment',
#  'annual_inc',
#  'pub_rec',
#  'total_acc',
#  'grade_A',
#  'grade_B',
#  'grade_C',
#  'grade_D',
#  'grade_E',
#  'grade_F',
#  'grade_G',
#  'emp_length_1 year',
#  'emp_length_10+ years',
#  'emp_length_2 years',
#  'emp_length_3 years',
#  'emp_length_4 years',
#  'emp_length_5 years',
#  'emp_length_6 years',
#  'emp_length_7 years',
#  'emp_length_8 years',
#  'emp_length_9 years',
#  'emp_length_< 1 year',
#  'emp_length_N/A',
#  'home_ownership_ANY',
#  'home_ownership_MORTGAGE',
#  'home_ownership_NONE',
#  'home_ownership_OWN',
#  'home_ownership_RENT',
#  'verification_status_Not Verified',
#  'verification_status_Source Verified',
#  'verification_status_Verified']

# %%
from time import time
nfast = 10      # Don't run the very slow ones
head = list(classifiers.items())[:nfast]

for name, classifier in head:
    start = time()
    classifier.fit(features, target)
    train_time = time() - start
    start = time()
    score = classifier.score(X_test[numerical], y_test)
    score_time = time()-start
    print("{:<15}| score = {:.3f} | time = {:,.3f}s/{:,.3f}s".format(name, score, train_time, score_time))
# Out:
# Dummy          | score = 0.496 | time = 0.004s/0.003s
# KNN(3)         | score = 0.579 | time = 0.015s/11.453s
# RBF SVM        | score = 0.817 | time = 2,373.119s/62.747s
# Decision Tree  | score = 0.602 | time = 0.446s/0.006s
# Random Forest  | score = 0.621 | time = 0.545s/0.016s
# Neural Net     | score = 0.218 | time = 28.144s/0.015s
# AdaBoost       | score = 0.591 | time = 5.168s/0.095s
# Naive Bayes    | score = 0.686 | time = 0.065s/0.008s
# QDA            | score = 0.746 | time = 0.191s/0.013s
# Linear SVC     | score = 0.831 | time = 20.521s/0.006s
