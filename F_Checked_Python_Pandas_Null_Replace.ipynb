# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/2022-PEA-ML-sklearn-Spark-/blob/main/F_Checked_Python_Pandas_Null_Replace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Null Replace เป็นการแทนที่ค่า Null ด้วยค่าคงที่ หรือค่าที่ได้จากการคำนวณ (Imputation)

# %%
# Create DataFrame with None/Null to work with examples
import pandas as pd
import numpy as np
technologies   = {
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          }
row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies, index=row_labels)
print(df)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %%
df.isnull().sum()
# Out:
# Courses     1
# Fee         1
# Duration    0
# Discount    0
# dtype: int64

# %%
df[df['Courses'].isnull()]
# Out:
#    Courses      Fee Duration  Discount
# r5    None  25000.0    35day      1300

# %%
#แทนที่ Null (None) เฉพาะใน Column 'Courses' ด้วย 'ยังไม่ได้ตั้งชื่อ'
df['Courses'] = df['Courses'].apply(lambda x: 'ยังไม่ได้ตั้งชื่อ' if x == None else x)
df
# Out:
#               Courses      Fee Duration  Discount
# r0              Spark  22000.0    30day      1000
# r1            PySpark  25000.0   50days      2300
# r2             Hadoop  23000.0   55days      1000
# r3             Python  24000.0   40days      1200
# r4             Pandas      NaN   60days      2500
# r5  ยังไม่ได้ตั้งชื่อ  25000.0    35day      1300
# r6              Spark  25000.0               1400
# r7             Python  22000.0   50days      1600

# %%
df
# Out:
#               Courses      Fee Duration  Discount
# r0              Spark  22000.0    30day      1000
# r1            PySpark  25000.0   50days      2300
# r2             Hadoop  23000.0   55days      1000
# r3             Python  24000.0   40days      1200
# r4             Pandas      NaN   60days      2500
# r5  ยังไม่ได้ตั้งชื่อ  25000.0    35day      1300
# r6              Spark  25000.0               1400
# r7             Python  22000.0   50days      1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, r0 to r7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   8 non-null      object
#  1   Fee       7 non-null      float64
#  2   Duration  8 non-null      object
#  3   Discount  8 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df[df['Fee'].isnull()]
# Out:
#    Courses  Fee Duration  Discount
# r4  Pandas  NaN   60days      2500

# %%
# แทนที่ NaN (None) เฉพาะใน Column 'Fee' ด้วยค่า Mean ของ 'Fee'
# โดยผลลัพธ์ยังคงเป็น Dataframe
df[['Fee']] = df[['Fee']].fillna(df['Fee'].mean())
df
# Out:
#               Courses           Fee Duration  Discount
# r0              Spark  22000.000000    30day      1000
# r1            PySpark  25000.000000   50days      2300
# r2             Hadoop  23000.000000   55days      1000
# r3             Python  24000.000000   40days      1200
# r4             Pandas  23714.285714   60days      2500
# r5  ยังไม่ได้ตั้งชื่อ  25000.000000    35day      1300
# r6              Spark  25000.000000               1400
# r7             Python  22000.000000   50days      1600

# %%
# แทนที่ NaN (None) เฉพาะใน Column 'Fee' ด้วยค่า Mean ของ 'Fee' 
# โดยผลลัพธ์เป็น Series

df['Fee'].fillna(df.Fee.mean())
# Out:
# r0    22000.000000
# r1    25000.000000
# r2    23000.000000
# r3    24000.000000
# r4    23714.285714
# r5    25000.000000
# r6    25000.000000
# r7    22000.000000
# Name: Fee, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, r0 to r7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   8 non-null      object
#  1   Fee       8 non-null      float64
#  2   Duration  8 non-null      object
#  3   Discount  8 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 620.0+ bytes

# %%
# กลับมาสำรวจดู Null อีกครั้ง และพบว่าไม่มี Null แล้ว

df[df.columns[df.isnull().any()]][df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: []
# Index: []
